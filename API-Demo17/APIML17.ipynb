# %%
import pandas as pd 
import requests

# %%
requests.get()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 requests.get()
#
# TypeError: get() missing 1 required positional argument: 'url'
