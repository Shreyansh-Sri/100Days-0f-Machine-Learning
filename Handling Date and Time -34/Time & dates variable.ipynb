# %%
import numpy as np
import pandas as pd

# %%
date = pd.read_csv('orders.csv')
time = pd.read_csv('messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# # Working with Dates

# %%
# Converting to datetime datatype
date['date'] = pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %% [markdown]
# # 1. Extract year

# %%
date['date_year'] = date['date'].dt.year

date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_month_no date_month_name  \
# 473 2019-05-15        1896       25       4              5             May
# 25  2018-09-14        4487       14       1              9       September
# 459 2019-05-02        3803       21       2              5             May
# 185 2019-11-29        4294       14       4             11        November
# 553 2019-05-29        2381       18       4              5             May
#
#      date_year
# 473       2019
# 25        2018
# 459       2019
# 185       2019
# 553       2019

# %% [markdown]
# # 2. Extract Month

# %%
date['date_month_no'] = date['date'].dt.month

date.head()
# Out:
#         date  product_id  city_id  orders  date_month_no
# 0 2019-12-10        5628       25       3             12
# 1 2018-08-15        3646       14     157              8
# 2 2018-10-23        1859       25       1             10
# 3 2019-08-17        7292       25       1              8
# 4 2019-01-06        4344       25       3              1

# %%
date['date_month_name'] = date['date'].dt.month_name()

date.head()
# Out:
#         date  product_id  city_id  orders  date_month_no date_month_name
# 0 2019-12-10        5628       25       3             12        December
# 1 2018-08-15        3646       14     157              8          August
# 2 2018-10-23        1859       25       1             10         October
# 3 2019-08-17        7292       25       1              8          August
# 4 2019-01-06        4344       25       3              1         January

# %% [markdown]
# # 3. Extract Days

# %%
date['date_day'] = date['date'].dt.day

date.head()
# Out:
#         date  product_id  city_id  orders  date_month_no date_month_name  \
# 0 2019-12-10        5628       25       3             12        December
# 1 2018-08-15        3646       14     157              8          August
# 2 2018-10-23        1859       25       1             10         October
# 3 2019-08-17        7292       25       1              8          August
# 4 2019-01-06        4344       25       3              1         January
#
#    date_year  date_day
# 0       2019        10
# 1       2018        15
# 2       2018        23
# 3       2019        17
# 4       2019         6

# %%
# day of week
date['date_dow'] = date['date'].dt.dayofweek

date.head()
# Out:
#         date  product_id  city_id  orders  date_month_no date_month_name  \
# 0 2019-12-10        5628       25       3             12        December
# 1 2018-08-15        3646       14     157              8          August
# 2 2018-10-23        1859       25       1             10         October
# 3 2019-08-17        7292       25       1              8          August
# 4 2019-01-06        4344       25       3              1         January
#
#    date_year  date_day  date_dow
# 0       2019        10         1
# 1       2018        15         2
# 2       2018        23         1
# 3       2019        17         5
# 4       2019         6         6

# %%
# day of week - name

date['date_dow_name'] = date['date'].dt.day_name()

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_month_no date_month_name  date_year  date_day  date_dow  \
# 0 2019-12-10             12        December       2019        10         1
# 1 2018-08-15              8          August       2018        15         2
# 2 2018-10-23             10         October       2018        23         1
# 3 2019-08-17              8          August       2019        17         5
# 4 2019-01-06              1         January       2019         6         6
#
#   date_dow_name
# 0       Tuesday
# 1     Wednesday
# 2       Tuesday
# 3      Saturday
# 4        Sunday

# %%
# is weekend?

date['date_is_weekend'] = np.where(date['date_dow_name'].isin(['Sunday', 'Saturday']), 1,0)

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_month_no date_month_name  date_year  date_day  date_dow  \
# 0 2019-12-10             12        December       2019        10         1
# 1 2018-08-15              8          August       2018        15         2
# 2 2018-10-23             10         October       2018        23         1
# 3 2019-08-17              8          August       2019        17         5
# 4 2019-01-06              1         January       2019         6         6
#
#   date_dow_name  date_is_weekend
# 0       Tuesday                0
# 1     Wednesday                0
# 2       Tuesday                0
# 3      Saturday                1
# 4        Sunday                1

# %% [markdown]
# # Extract week of the year

# %%
date['date_week'] = date['date'].dt.isocalendar().week

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_month_no date_month_name  date_year  date_day  date_dow  \
# 0 2019-12-10             12        December       2019        10         1
# 1 2018-08-15              8          August       2018        15         2
# 2 2018-10-23             10         October       2018        23         1
# 3 2019-08-17              8          August       2019        17         5
# 4 2019-01-06              1         January       2019         6         6
#
#   date_dow_name  date_is_weekend  date_week
# 0       Tuesday                0         50
# 1     Wednesday                0         33
# 2       Tuesday                0         43
# 3      Saturday                1         33
# 4        Sunday                1          1

# %% [markdown]
# # Extract Quarter

# %%
date['quarter'] = date['date'].dt.quarter

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_month_no date_month_name  date_year  date_day  date_dow  \
# 0 2019-12-10             12        December       2019        10         1
# 1 2018-08-15              8          August       2018        15         2
# 2 2018-10-23             10         October       2018        23         1
# 3 2019-08-17              8          August       2019        17         5
# 4 2019-01-06              1         January       2019         6         6
#
#   date_dow_name  date_is_weekend  date_week  quarter
# 0       Tuesday                0         50        4
# 1     Wednesday                0         33        3
# 2       Tuesday                0         43        4
# 3      Saturday                1         33        3
# 4        Sunday                1          1        1

# %% [markdown]
# # Extract Semester

# %%
date['semester'] = np.where(date['quarter'].isin([1,2]), 1, 2)

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_month_no date_month_name  date_year  date_day  date_dow  \
# 0 2019-12-10             12        December       2019        10         1
# 1 2018-08-15              8          August       2018        15         2
# 2 2018-10-23             10         October       2018        23         1
# 3 2019-08-17              8          August       2019        17         5
# 4 2019-01-06              1         January       2019         6         6
#
#   date_dow_name  date_is_weekend  date_week  quarter  semester
# 0       Tuesday                0         50        4         2
# 1     Wednesday                0         33        3         2
# 2       Tuesday                0         43        4         2
# 3      Saturday                1         33        3         2
# 4        Sunday                1          1        1         1

# %% [markdown]
# # Extract Time elapsed between dates

# %%
import datetime

today = datetime.datetime.today()

today
# Out:
# datetime.datetime(2026, 7, 9, 1, 19, 41, 646794)

# %%
today - date['date']
# Out:
# 0     2403 days 01:19:41.646794
# 1     2885 days 01:19:41.646794
# 2     2816 days 01:19:41.646794
# 3     2518 days 01:19:41.646794
# 4     2741 days 01:19:41.646794
#                  ...
# 995   2831 days 01:19:41.646794
# 996   2772 days 01:19:41.646794
# 997   2620 days 01:19:41.646794
# 998   2685 days 01:19:41.646794
# 999   2459 days 01:19:41.646794
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today - date['date']).dt.days
# Out:
# 0      2403
# 1      2885
# 2      2816
# 3      2518
# 4      2741
#        ...
# 995    2831
# 996    2772
# 997    2620
# 998    2685
# 999    2459
# Name: date, Length: 1000, dtype: int64

# %%
# Months passed
date['months_passed'] = (
    (today.year - date['date'].dt.year) * 12
    + (today.month - date['date'].dt.month)
)

date['months_passed']
# Out:
# 0      79
# 1      95
# 2      93
# 3      83
# 4      90
#        ..
# 995    93
# 996    91
# 997    86
# 998    88
# 999    81
# Name: months_passed, Length: 1000, dtype: int32

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
# Converting to datetime datatype
time['date'] = pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
time['hour'] = time['date'].dt.hour
time['min'] = time['date'].dt.minute
time['sec'] = time['date'].dt.second

time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec
# 0     0   50    0
# 1    23   40    0
# 2     0   21    0
# 3     0   31    0
# 4    23   11    0

# %% [markdown]
# # Extract Time part

# %%
time['time'] = time['date'].dt.time

time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec      time
# 0     0   50    0  00:50:00
# 1    23   40    0  23:40:00
# 2     0   21    0  00:21:00
# 3     0   31    0  00:31:00
# 4    23   11    0  23:11:00

# %% [markdown]
# # Time difference

# %%
today - time['date']
# Out:
# 0     4589 days 00:29:41.646794
# 1     4453 days 01:39:41.646794
# 2     4939 days 00:58:41.646794
# 3     4241 days 00:48:41.646794
# 4     4638 days 02:08:41.646794
#                  ...
# 995   5228 days 00:29:41.646794
# 996   4549 days 02:05:41.646794
# 997   5014 days 01:42:41.646794
# 998   5130 days 01:45:41.646794
# 999   4402 days 01:54:41.646794
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
# in seconds

(today - time['date'])/np.timedelta64(1,'s')
# Out:
# 0      3.964914e+08
# 1      3.847452e+08
# 2      4.267331e+08
# 3      3.664253e+08
# 4      4.007309e+08
#            ...
# 995    4.517010e+08
# 996    3.930411e+08
# 997    4.332158e+08
# 998    4.432383e+08
# 999    3.803397e+08
# Name: date, Length: 1000, dtype: float64

# %%
# in minutes

(today - time['date'])/np.timedelta64(1,'m')
# Out:
# 0      6.608190e+06
# 1      6.412420e+06
# 2      7.112219e+06
# 3      6.107089e+06
# 4      6.678849e+06
#            ...
# 995    7.528350e+06
# 996    6.550686e+06
# 997    7.220263e+06
# 998    7.387306e+06
# 999    6.338995e+06
# Name: date, Length: 1000, dtype: float64

# %%
# in hours

(today - time['date'])/np.timedelta64(1,'h')
# Out:
# 0      110136.494902
# 1      106873.661569
# 2      118536.978235
# 3      101784.811569
# 4      111314.144902
#            ...
# 995    125472.494902
# 996    109178.094902
# 997    120337.711569
# 998    123121.761569
# 999    105649.911569
# Name: date, Length: 1000, dtype: float64
