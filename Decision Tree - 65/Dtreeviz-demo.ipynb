# %%
#!pip install dtreeviz

# %%
import graphviz.backend as be

# %%
from sklearn.datasets import load_iris
from dtreeviz import model
from IPython.display import Image, display_svg, SVG
from sklearn import tree

# %%
clas = tree.DecisionTreeClassifier(max_depth=2)  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.043\nsamples = 46\nvalue = [0, 1, 45]')]

# %% [markdown]
# # 1. Classification

# %%
viz =model(clas, 
               X_train,
               y_train,
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"]
          )           
viz

# %%
#viz.view()

# %% [markdown]
# # 2. Regression

# %%
from sklearn.datasets import fetch_california_housing
regr = tree.DecisionTreeRegressor(max_depth=1)
boston =fetch_california_housing()

X_train = boston.data
y_train = boston.target
regr.fit(X_train, y_train)

viz = dtreeviz(regr,
               X_train,
               y_train,
               target_name='price',
               feature_names=boston.feature_names,
               scale=2
              )
viz
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17144\34402249.py:9: DeprecationWarning: dtreeviz() function is deprecated starting from version 2.0.
#  For the same functionality, please use this code instead:
#  m = dtreeviz.model(...)
#  m.view()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 9
#       5 X_train = boston.data
#       6 y_train = boston.target
#       7 regr.fit(X_train, y_train)
#       8
# ----> 9 viz = dtreeviz(regr,
#      10                X_train,
#      11                y_train,
#      12                target_name='price',
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\dtreeviz\compatibility.py:254, in dtreeviz(tree_model, X_train, y_train, feature_names, target_name, class_names, tree_index, precision, orientation, instance_orientation, show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, highlight_path, X, max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize, fontname, title, title_fontsize, colors, scale)
#     251 shadow_tree = ShadowDecTree.get_shadow_tree(tree_model, X_train, y_train, feature_names, target_name, class_names,
#     252                                             tree_index)
#     253 model = DTreeVizAPI(shadow_tree)
# --> 254 return model.view(precision, orientation,
#     255                   instance_orientation,
#     256                   show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, highlight_path, X,
#     257                   max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize,
#     258                   fontname, title, title_fontsize, colors=colors, scale=scale)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\dtreeviz\trees.py:837, in DTreeVizAPI.view(self, precision, orientation, instance_orientation, show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, leaftype, highlight_path, x, max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize, fontname, title, title_fontsize, colors, scale, ai_chat)
#     835 tmp = tempfile.gettempdir()
#     836 if x is not None:
# --> 837     path = self.shadow_tree.predict_path(x)
#     838     highlight_path = [n.id for n in path]
#     839     path_summary_text = _summarize_path_for_chat(path)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\dtreeviz\models\shadow_decision_tree.py:340, in ShadowDecTree.predict_path(self, x)
#     337     return walk(t.right, x, path)
#     339 path = []
# --> 340 walk(self.root, x, path)
#     341 return path
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\dtreeviz\models\shadow_decision_tree.py:335, in ShadowDecTree.predict_path.<locals>.walk(t, x, path)
#     333 if t.isleaf():
#     334     return None
# --> 335 if self.shouldGoLeftAtSplit(t.id, x[t.feature()]):
#     336     return walk(t.left, x, path)
#     337 return walk(t.right, x, path)
#
# TypeError: 'int' object is not subscriptable
